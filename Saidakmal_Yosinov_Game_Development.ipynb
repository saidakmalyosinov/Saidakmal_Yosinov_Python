# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Jan 226 10:20:46 2022

@author: Saidakmal Yosinov
"""
    # Docstring
"""
    DocString:
    
    A) Introduction:
    This game is based on the TV show 'Are You Smarter Than a Fifth-Grader?'. 
    This game is intended for recent school graduates and older, 
    as it evaluates the  intellectual abilities and tests the knowledge acquired at school. 
    The game consists of 3 rounds and it asks questions exclusively from the school curriculum. 
    With the passage of each round, the questions become more and more difficult. 
    To win this game you have to answer all questions correctly.
  
    Round 1: Questions from elementary school. Level is easy.
    Round 2: Questions from middle school. Level is normal.
    Round 3: Questions from high school. Level is hard.
    
    B) Known Bugs and/or Errors:
    None.
    
"""
# importing necessary packages
from sys import exit
import random
import time

#########################################################
# Constructing start session with game description and user introduction
######################################################### 
# defining a function
def start():
    print("""
         Welcome to our game. 
         If you're a competent adult with a grade-school kid, this probably wasn't news to you. 
         You probably struggle in the same way when you try to help your son or daughter with their homework. 
         What was Teapot Dome about, again? How do you write 2/3 as a decimal? 
         Even if you don't have a school-age child, 
         maybe you're eager to find out how much you remember from your grammar school days. 
         If so, we've got a quiz to help you out. 
         Don't worry... Even if you do badly, we'll still sit with you at lunch!
         """)
    print("Before we start a game, please introduce yourself.")
    name = input(prompt = "\nYour name: \n")
    print(f"\nNice to meet you {name.capitalize()}!\n") # shows print statement with name of user with capital letter
    start_choices()

#########################################################
# Constructing start_choices session and calling it to start the game   
######################################################### 

# defining a function
def start_choices():
    print("""\nAre you ready to start a game?\n
        """)
    
    start_choice = input(prompt = "\nPlease enter: Yes or No \n")
    start_choice = start_choice.capitalize()
    # conditional statement
    # based on user input, the game will provide three options. If user inputs 'Yes', the countdown starts 3...2...1...Let's go! and user is transferred to first round of a game. 
    if "Yes" in start_choice:
        # declaring object
        count = 3
        # looping until count equals zero
        while count > 0:
            print(count)
            count -= 1
            time.sleep(0.5) # pausing the kernel, it counts 50% of 1 second
    
        print("Let's go!")
        easy_question_1() # this moves user into the first level of game   
    # if user inputs 'No', below print statement occurs and he/she is transferred to fail session in which games is over.    
    elif "No" in start_choice:
        print("Looks like you're not ready yet. As soon as you want to play this game, be sure to come.")
        fail() # this moves user into fail
    # if user inputs neither yes or no, he/she is given another chance to input value yes or no.    
    else:
        print("Invalid entry. Please try again.\n")
        start_choices() # this moves user into start_choices
        
#########################################################
# Constructing the first round of game
######################################################### 

# defining a function
def easy_question_1():
    # printing
    print("""
        Please read the first question and input one of 4 available answers.
        """)
    # printing
    print("""
        The top number of a fraction is called the numerator. What is the bottom number called?
        1) numerated
        2) sine
        3) denominator
        4) factorial
        """)
    
    easy_answer_1 = input(prompt = ">  \n") #user input
    easy_answer_1 = easy_answer_1.lower() # user input is read as lower case letters
    # conditional statement
    if "3" in easy_answer_1 or "denominator" in easy_answer_1: # if 3 or denominator exists in user input, he/she will be given second question.
        print("\nCorrect answer! Good for a start.\n")
        input(prompt = "<Press enter to start the second question.>\n")
        easy_question_2() # this moves user into the second question of first round
    # if sine or denominator or factorial or 1 or 2 or 4 exists in user input, he/she will lose the game.
    elif "sine" in easy_answer_1 or "denominator" in easy_answer_1 or "factorial" in easy_answer_1 or "1" in easy_answer_1 or "2" in easy_answer_1 or "4" in easy_answer_1:
        print("\nWrong answer! It would be nice to repeat the school material in mathematics.")
        fail()  # this moves user into fail session in which the game ends
    # if user inserted something different, he/she will be given other tries to input new values.
    else:
        print("No such answer exists. Please try again.")
        easy_question_1() # this moves user into the first question of the first level
        
# defining a function        
def easy_question_2():
    print("""
        What is New Mexico?
        1) state
        2) country
        3) island
        4) city
        """)
    
    easy_answer_2 = input(prompt = ">  \n")
    easy_answer_2 = easy_answer_2.lower()
    
    # conditional statement based on user input
    if "1" in easy_answer_2 or "state" in easy_answer_2:
        print("\nCorrect answer. Good knowledge in geography.\n")
        input(prompt = "<Press enter to start the third question.>\n")
        easy_question_3() # this moves user into the third question of the first round
    
    elif "2" in easy_answer_2 or "country" in easy_answer_2 or "3" in easy_answer_2 or "island" in easy_answer_2 or "city" in easy_answer_2 or "4" in easy_answer_2:
        print("""\nWrong answer! Disturbingly, a number of people don't realize that New Mexico is a state just east of Arizona.""")
        fail() # this moves user into fail session in which the game ends
    
    else:
        print("No such answer exists. Please try again.")
        easy_question_2()
        
# defining a function        
def easy_question_3():
    print("""
        The planet closest to the Sun is ... ?
        1) Earth
        2) Mercury
        3) Jupiter
        4) Mars
        """)
    
    easy_answer_3 = input(prompt = ">  \n")
    easy_answer_3 = easy_answer_3.capitalize()
    
    # conditional statement based on user input
    if "2" in easy_answer_3 or "Mercury" in easy_answer_3:
        print("\nCorrect Answer!: Mercury is a small planet, and the one closest to our star.\n")
        input(prompt = "<Press enter to start the fourth question.>\n")
        easy_question_4() # this moves user into the fourth question of the first round
    
    elif "1" in easy_answer_3 or "Earth" in easy_answer_3 or "3" in easy_answer_3 or "Jupiter" in easy_answer_3 or "Mars" in easy_answer_3 or "4" in easy_answer_3:
        print("""\nWrong answer! Apparently you weren't interested in astronomy at school.\n""")
        fail()   # this moves user into fail session in which the game ends
    
    else:
        print("No such answer exists. Please try again.")
        easy_question_3()
        
# defining a function        
def easy_question_4():
    print("""
        Which of these refers to a young deer?
        1) babe
        2) pup
        3) trout
        4) fawn
        """)
    
    easy_answer_4 = input(prompt = ">  \n")
    easy_answer_4 = easy_answer_4.lower()
    
    # conditional statement based on user input
    if "4" in easy_answer_4 or "fawn" in easy_answer_4:
        print("\nCorrect Answer! Young deer are called fawns. This name has lent itself to a color - a pale brown.\n")
        input(prompt = "<Press enter to start the fifth question.>\n")
        easy_question_5() # this moves user into the fifth question of the first round
    
    elif "1" in easy_answer_4 or "babe" in easy_answer_4 or "2" in easy_answer_4 or "pup" in easy_answer_4 or "trout" in easy_answer_3 or "3" in easy_answer_4:
        print("""\nWrong answer! It would be nice to improve your knowledge in the field of zoology.\n""")
        fail()   # this moves user into fail session in which the game ends
    
    else:
        print("No such answer exists. Please try again.")
        easy_question_4()
        
# defining a function        
def easy_question_5():
    print("""
        What does a "legislator" make?
        1) laws
        2) airplanes
        3) guns
        4) newspapers
        """)
    
    easy_answer_5 = input(prompt = ">  \n")
    easy_answer_5 = easy_answer_5.lower()
    
    # conditional statement based on user input
    if "1" in easy_answer_5 or "laws" in easy_answer_5 or "law" in easy_answer_5:
        print("\nCorrect Answer! Congress, made up of the House of Representatives and the Senate, is America's legislative body.\nIn many other countries, this body is called a Parliament.\n")
        input(prompt = "<Press enter to go to the next level.>\n")
        normal_questions() # this moves user into second level of game.
    
    elif "2" in easy_answer_5 or "airplanes" in easy_answer_5 or "airplane" in easy_answer_5 or "3" in easy_answer_5 or "guns" in easy_answer_5 or "gun" in easy_answer_5 or "newspapers" in easy_answer_5 or "newspaper" in easy_answer_5 or "4" in easy_answer_5:
        print("""\nWrong answer! There was only one step left to go to the next level.
                   Unfortunately, insufficient knowledge in the field of law let you down.\n""")
        fail()   # this moves user into fail session in which the game ends
    
    else:
        print("No such answer exists. Please try again.")
        easy_question_5()
        
# defining a function
def normal_questions():
    print("""
        Congratulations on passing the first level! 
        As you noticed there were multiple choice questions in the first round. 
        But now the game is changing.
        In this round, the type of questions will be open and you will have to find the answers to the questions yourself.
        """)
    # asking user to press ENTER to continue a game
    input(prompt = "<Press enter to start questions from the second round.> \n")
    # declaring a list of questions
    question_list = ['What is the smallest prime number?',
                     'Who was the first president of the USA?',
                     'What is one-third of 60?',
                     'How many sides are present in a hexagon?',
                     'Which planet is the hottest in our Solar System?',
                     'Which is the most abundant gas in our atmosphere?',
                     'When exposed to acid, what color does litmus paper turn?',
                     'What substance makes up 71% of the Earth?',
                     'Which fish is known for not having any brain or heart?',
                     'Which city’s nickname in the USA is "Windy City"?']
    # declaring object
    questions = 5
    # looping until a user answers 5 questions out of 10 questions
    while questions > 0:
        # this will generate a random question among 10 available questions in the list
        question = random.choice(question_list)
        print(question)
        print(" ")
        
        if question == question_list[0]:
            normal_answer_1 = input(prompt = "> \n")
            normal_answer_1 = normal_answer_1.lower()
             # conditional statement based on user input
            if '2' in normal_answer_1 or 'two' in normal_answer_1:
                print("\nGreat job!\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer!\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[1]:
            normal_answer_2 = input(prompt = "> \n")
            normal_answer_2 = normal_answer_2.capitalize()
             # conditional statement based on user input
            if 'George Washington' in normal_answer_2 or 'Washington' in normal_answer_2 or 'G. Washington' in normal_answer_2 or 'Washington George' in normal_answer_2 or 'George' in normal_answer_2:
                print("\nGreat job!\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer!\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
                
        elif question == question_list[2]:
            normal_answer_3 = input(prompt = "> \n")
            normal_answer_3 = normal_answer_3.lower()
             # conditional statement based on user input
            if '20' in normal_answer_3 or 'twenty' in normal_answer_3:
                print("\nGreat job! The correct answer is 20.\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer!\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
            
        elif question == question_list[3]:
            normal_answer_4 = input(prompt = "> \n")
            normal_answer_4 = normal_answer_4.lower()
             # conditional statement based on user input
            if 'six' in normal_answer_4 or '6' in normal_answer_4:
                print("\nGreat job! Six sides are present in a hexagon.\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer!\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[4]:
            normal_answer_5 = input(prompt = "> \n")
            normal_answer_5 = normal_answer_5.capitalize()
             # conditional statement based on user input
            if 'Venus' in normal_answer_5:
                print("\nGreat job! Venus is the hottest planet in our solar system.\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is Venus.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[5]:
            normal_answer_6 = input(prompt = "> \n")
            normal_answer_6 = normal_answer_6.capitalize()
             # conditional statement based on user input
            if 'Nitrogen' in normal_answer_6:
                print("\nGreat job! Nitrogen makes over 78% of earth’s atmosphere.\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is nitrogen.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[6]:
            normal_answer_7 = input(prompt = "> \n")
            normal_answer_7 = normal_answer_7.lower()
             # conditional statement based on user input
            if 'red' in normal_answer_7:
                print("\nGreat job!\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is red.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[7]:
            normal_answer_8 = input(prompt = "> \n")
            normal_answer_8 = normal_answer_8.lower()
             # conditional statement based on user input
            if 'water' in normal_answer_8 or 'h2o' in normal_answer_8 or 'hydrogen oxide' in normal_answer_8:
                print("\nGreat job!\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer! Correct answer is water.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[8]:
            normal_answer_9 = input(prompt = "> \n")
            normal_answer_9 = normal_answer_9.lower()
             # conditional statement based on user input
            if 'jellyfish' in normal_answer_9:
                print("\nGreat job!\n")
                questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is jellyfish.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif question == question_list[9]:
            normal_answer_10 = input(prompt = "> \n")
            normal_answer_10 = normal_answer_10.capitalize()
             # conditional statement based on user input
            if 'Chicago' in normal_answer_10:
                print("\nGreat job!\n")
            else:
                print(f"\nWrong answer! Correct answer is Chicago.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
        
        else:
            print("Invalid entry. Please try again.\n")
            normal_questions() # Brings us back to the beginning of second level to try again
                
        
    print("Congratulations! You correctly answered all 5 questions from the second level.\n")
    input(prompt = "<Press enter to go to the third level.>\n")
    hard_questions() # this moves user into third round of the game

def hard_questions():
    print("""You have successfully completed the previous two levels of our game, 
             which already proves the presence of high intellectual abilities. 
             In the last round, you only have to answer 3 questions. 
             However, compared to the questions from previous rounds, these questions will be much more difficult. 
             Therefore, I ask you to concentrate and make efforts to correctly answer these three questions.
             """)
    # asking user to press ENTER to continue a game
    input(prompt = "<Press enter to start questions from the third round.> \n")
    
    # declaring a list of questions
    hard_question_list = ['Which element was discovered by the French chemists Marie Curie and Pierre Curie?',
                     'Which company is the largest producer of computer software for personal computers?',
                     'What do you call a village that does not have a church?',
                     '________ is the basic unit of all living things?',
                     'On which body part a temporal lobe is placed?',
                     'The world’s oldest city is?']
    
    # declaring object
    hard_questions = 3
    
    # looping until a user answers 3 questions out of 6 questions
    while hard_questions > 0:
        # this will generate a random question among 6 available questions in the list
        hard_question = random.choice(hard_question_list)
        print(hard_question)
        print(" ")
        
        if hard_question == hard_question_list[0]:
            hard_answer_1 = input(prompt = "> \n")
            hard_answer_1 = hard_answer_1.capitalize()
             # conditional statement based on user input
            if 'Radium' in hard_answer_1 or 'Ra' in hard_answer_1:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer! The correct answer is Radium.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif hard_question == hard_question_list[1]:
            hard_answer_2 = input(prompt = "> \n")
            hard_answer_2 = hard_answer_2.upper()
             # conditional statement based on user input
            if 'MICROSOFT' in hard_answer_2 or 'MSFT' in hard_answer_2 or 'MS' in hard_answer_2 or 'MSAP' in hard_answer_2 or 'M$' in hard_answer_2:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print("\nWrong answer! The correct answer is MICROSOFT.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
                
        elif hard_question == hard_question_list[2]:
            hard_answer_3 = input(prompt = "> \n")
            hard_answer_3 = hard_answer_3.lower()
             # conditional statement based on user input
            if 'hamlet' in hard_answer_3:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! The correct answer is hamlet.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
            
        elif hard_question == hard_question_list[3]:
            hard_answer_4 = input(prompt = "> \n")
            hard_answer_4 = hard_answer_4.lower()
             # conditional statement based on user input
            if 'cell' in hard_answer_4:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! The correct answer is cell.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif hard_question == hard_question_list[4]:
            hard_answer_5 = input(prompt = "> \n")
            hard_answer_5 = hard_answer_5.lower()
             # conditional statement based on user input
            if 'brain' in hard_answer_5:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is brain.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        elif hard_question == hard_question_list[5]:
            hard_answer_6 = input(prompt = "> \n")
            hard_answer_6 = hard_answer_6.capitalize()
             # conditional statement based on user input
            if 'Damascus' in hard_answer_6:
                print("\nGreat job!\n")
                hard_questions -=1 # number of questions decreases by 1 if user inputs correct answer
            else:
                print(f"\nWrong answer! Correct answer is Damascus.\n")
                fail() # once user inputs incorrect answer, this will move user to fail session
                break # this line of code stops running while loop
                
        else:
            print("Invalid entry. Please try again.\n")
            hard_questions() # Brings us back to the beginning of third level to try again
                
    victory() # this will move user into victory session
    
# defining a function
def victory():
    print("""You have completed your quest for 'Are You Smarter Than a Fifth-Grader?'! Great job!
          """)
    input(prompt = "<Press enter to exit, you champion!>\n")
    exit() # game ends
    
#defining a function    
def fail():
    print("\nYou have failed in your quest for 'Are You Smarter Than a Fifth-Grader?'.")
    restart_game = input(prompt = '''Would you like to play again? (YES or NO)\n''').upper()
    if "YES" in restart_game:
        print("Well, let's check the intellectual abilites again!")
        easy_question_1() # game restarts from level 1
    elif "NO" in restart_game:
            try: #to end the code
                print("\n Game Over!\n")
                exit() # game ends
            except: # alternative way to end for try
                quit() # game ends
    else:
            fail() # restarts fail function
    
start() # everything goes before this clause
# Out:
#          Welcome to our game.
#          If you're a competent adult with a grade-school kid, this probably wasn't news to you.
#          You probably struggle in the same way when you try to help your son or daughter with their homework.
#          What was Teapot Dome about, again? How do you write 2/3 as a decimal?
#          Even if you don't have a school-age child,
#          maybe you're eager to find out how much you remember from your grammar school days.
#          If so, we've got a quiz to help you out.
#          Don't worry... Even if you do badly, we'll still sit with you at lunch!
#
# Before we start a game, please introduce yourself.
#
# Your name:
# af
#
# Nice to meet you Af!
#
#
# Are you ready to start a game?
#
#
#
# Please enter: Yes or No
# yes
# 3
# 2
# 1
# Let's go!
#
#         Please read the first question and input one of 4 available answers.
#
#
#         The top number of a fraction is called the numerator. What is the bottom number called?
# ...
